# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df1= pd.read_csv('dataset.csv')
df1.head()
# Out:
#   Manufacturer Version  Power(kwh)   Route/Area  Weather   Humidity(%)  \
# 0   Volkswagen  e-Golf          33  Munich East       1.0         0.64
# 1   Volkswagen  e-Golf          33  Munich East       1.0         0.64
# 2   Volkswagen  e-Golf          33  Munich East       1.0         0.64
# 3   Volkswagen  e-Golf          33  Munich East       1.0         0.64
# 4   Volkswagen  e-Golf          33  Munich East       1.0         0.64
#
#    Battery Temperature (Start) [°C]  Battery Temperature (End)  \
# 0                                21                         22
# 1                                23                         26
# 2                                24                         25
# 3                                25                         27
# 4                                27                         27
#
#    Battery State of Charge (Start)  Battery State of Charge (End)  \
# 0                             0.86                           0.80
# 1                             0.80                           0.67
# 2                             0.84                           0.75
# 3                             0.75                           0.67
# 4                             0.67                           0.60
#
#    Battery Consumption  Battery Consumption(in kwh)  \
# 0                 0.06                         1.98
# 1                 0.13                         4.29
# 2                 0.08                         2.64
# 3                 0.08                         2.64
# 4                 0.07                         2.31
#
#    Ambient Temperature (Start) [°C]  Target Cabin Temperature  Distance [km]  \
# 0                              25.5                      23.0           7.43
# 1                              32.0                      23.0          23.51
# 2                              21.5                      27.0          12.82
# 3                              24.0                      22.0          10.73
# 4                              24.5                      24.0          12.39
#
#    Distance[miles]  Duration [hr]  Average Speed  \
# 0             4.61           0.28          26.50
# 1            14.58           0.39          59.90
# 2             7.95           0.19          68.81
# 3             6.65           0.11          93.69
# 4             7.68           0.38          32.65
#
#    Full battery Mileage(Mi/kwh)  Mileage Acc To Distance (Mi/kwh)
# 0                          3.58                              2.33
# 1                          3.58                              3.40
# 2                          3.58                              3.01
# 3                          3.58                              2.52
# 4                          3.58                              3.33

# %%
df2 = df1.drop(['Route/Area','Distance [km]','Version','Battery Consumption','Full battery Mileage(Mi/kwh)'],axis=1)
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df2['Manufacturer']= label_encoder.fit_transform(df2['Manufacturer'])
df2.to_csv('final_datset.csv',index=False)
df2.head()
# Out:
#    Manufacturer  Power(kwh)  Weather   Humidity(%)  \
# 0             1          33       1.0         0.64
# 1             1          33       1.0         0.64
# 2             1          33       1.0         0.64
# 3             1          33       1.0         0.64
# 4             1          33       1.0         0.64
#
#    Battery Temperature (Start) [°C]  Battery Temperature (End)  \
# 0                                21                         22
# 1                                23                         26
# 2                                24                         25
# 3                                25                         27
# 4                                27                         27
#
#    Battery State of Charge (Start)  Battery State of Charge (End)  \
# 0                             0.86                           0.80
# 1                             0.80                           0.67
# 2                             0.84                           0.75
# 3                             0.75                           0.67
# 4                             0.67                           0.60
#
#    Battery Consumption(in kwh)  Ambient Temperature (Start) [°C]  \
# 0                         1.98                              25.5
# 1                         4.29                              32.0
# 2                         2.64                              21.5
# 3                         2.64                              24.0
# 4                         2.31                              24.5
#
#    Target Cabin Temperature  Distance[miles]  Duration [hr]  Average Speed  \
# 0                      23.0             4.61           0.28          26.50
# 1                      23.0            14.58           0.39          59.90
# 2                      27.0             7.95           0.19          68.81
# 3                      22.0             6.65           0.11          93.69
# 4                      24.0             7.68           0.38          32.65
#
#    Mileage Acc To Distance (Mi/kwh)
# 0                              2.33
# 1                              3.40
# 2                              3.01
# 3                              2.52
# 4                              3.33

# %%
#df2['Humidity(%)'] = df2['Humidity(%)']*100
df2['Battery State of Charge (Start)'] = df2['Battery State of Charge (Start)']*100
df2['Battery State of Charge (End)'] = df2['Battery State of Charge (End)']*100
df2.head()
# Out:
#    Manufacturer  Power(kwh)  Weather   Humidity(%)  \
# 0             1          33       1.0         64.0
# 1             1          33       1.0         64.0
# 2             1          33       1.0         64.0
# 3             1          33       1.0         64.0
# 4             1          33       1.0         64.0
#
#    Battery Temperature (Start) [°C]  Battery Temperature (End)  \
# 0                                21                         22
# 1                                23                         26
# 2                                24                         25
# 3                                25                         27
# 4                                27                         27
#
#    Battery State of Charge (Start)  Battery State of Charge (End)  \
# 0                             86.0                           80.0
# 1                             80.0                           67.0
# 2                             84.0                           75.0
# 3                             75.0                           67.0
# 4                             67.0                           60.0
#
#    Battery Consumption(in kwh)  Ambient Temperature (Start) [°C]  \
# 0                         1.98                              25.5
# 1                         4.29                              32.0
# 2                         2.64                              21.5
# 3                         2.64                              24.0
# 4                         2.31                              24.5
#
#    Target Cabin Temperature  Distance[miles]  Duration [hr]  Average Speed  \
# 0                      23.0             4.61           0.28          26.50
# 1                      23.0            14.58           0.39          59.90
# 2                      27.0             7.95           0.19          68.81
# 3                      22.0             6.65           0.11          93.69
# 4                      24.0             7.68           0.38          32.65
#
#    Mileage Acc To Distance (Mi/kwh)
# 0                              2.33
# 1                              3.40
# 2                              3.01
# 3                              2.52
# 4                              3.33

# %%
x = df2.drop(['Mileage Acc To Distance (Mi/kwh)'],axis=1)
x.head()
# Out:
#    Manufacturer  Power(kwh)  Weather   Humidity(%)  \
# 0             1          33       1.0         64.0
# 1             1          33       1.0         64.0
# 2             1          33       1.0         64.0
# 3             1          33       1.0         64.0
# 4             1          33       1.0         64.0
#
#    Battery Temperature (Start) [°C]  Battery Temperature (End)  \
# 0                                21                         22
# 1                                23                         26
# 2                                24                         25
# 3                                25                         27
# 4                                27                         27
#
#    Battery State of Charge (Start)  Battery State of Charge (End)  \
# 0                             86.0                           80.0
# 1                             80.0                           67.0
# 2                             84.0                           75.0
# 3                             75.0                           67.0
# 4                             67.0                           60.0
#
#    Battery Consumption(in kwh)  Ambient Temperature (Start) [°C]  \
# 0                         1.98                              25.5
# 1                         4.29                              32.0
# 2                         2.64                              21.5
# 3                         2.64                              24.0
# 4                         2.31                              24.5
#
#    Target Cabin Temperature  Distance[miles]  Duration [hr]  Average Speed
# 0                      23.0             4.61           0.28          26.50
# 1                      23.0            14.58           0.39          59.90
# 2                      27.0             7.95           0.19          68.81
# 3                      22.0             6.65           0.11          93.69
# 4                      24.0             7.68           0.38          32.65

# %%
y=df2['Mileage Acc To Distance (Mi/kwh)']
y.head()
# Out:
# 0    2.33
# 1    3.40
# 2    3.01
# 3    2.52
# 4    3.33
# Name: Mileage Acc To Distance (Mi/kwh), dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)
X_train.mean()
# Out:
# 0.4311959343859087

# %%
import seaborn as sns
f, ax = plt.subplots(figsize=(10, 8))
corr = df2.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
square=True, ax=ax,annot=True)
plt.show()
# Out:
# /var/folders/4z/blwff4q561x5lcwhc8jtf9m80000gn/T/ipykernel_1978/2117891625.py:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),

# %%
# Evaluation Metrics
from sklearn import metrics
def print_error(X_test, y_test, model_name):
  prediction = model_name.predict(X_test)
  print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, prediction))
  print('Mean Squared Error:', metrics.mean_squared_error(y_test, prediction))
  print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))

# Linear Regression
from sklearn import linear_model
linear_regression = linear_model.LinearRegression()
linear_regression.fit(X_train, y_train)
print_error(X_test,y_test, linear_regression)

# Support Vector Regressor
from sklearn.svm import SVR
supportvector_regressor = SVR()
supportvector_regressor.fit(X_train,y_train)
print_error(X_test,y_test,supportvector_regressor)
# Out:
# Mean Absolute Error: 0.7528414300303634
# Mean Squared Error: 0.872392446786176
# Root Mean Squared Error: 0.9340195109237152
# Mean Absolute Error: 0.21986639313882778
# Mean Squared Error: 0.08220437075876905
# Root Mean Squared Error: 0.28671304602122494

# %%
# Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor
decision_tree = DecisionTreeRegressor()
decision_tree.fit(X_train, y_train)
print_error(X_test,y_test, decision_tree)

# Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
n_estimators = 200
max_depth = 25
min_samples_split=15
min_samples_leaf=2
random_forest = RandomForestRegressor(n_estimators = n_estimators, max_depth = max_depth, min_samples_split=min_samples_split)
random_forest.fit(X_train,y_train)
print_error(X_test,y_test, random_forest)
# Out:
# Mean Absolute Error: 0.4978571428571429
# Mean Squared Error: 0.43417857142857147
# Root Mean Squared Error: 0.6589222802641989
# Mean Absolute Error: 0.24611334164795565
# Mean Squared Error: 0.11652503018098026
# Root Mean Squared Error: 0.34135762798124236

# %%
#Saving Scikitlearn models
import pickle
with open('model_pickle','wb') as file:
    pickle.dump(supportvector_regressor,file)

# %%
with open('model_pickle','rb') as file:
    bmp = pickle.load(file)

# %%
bmp.predict(X_test)
# Out:
# array([3.13629532, 2.04305472, 1.6662519 , 2.93591115, 1.63047007,
#        2.11297956, 3.34637087, 2.01360299, 1.64684533, 3.13672594,
#        2.48133299, 1.5231751 , 3.02236254, 1.63755948])

# %%
bmp.score(X_test,y_test)
# Out:
# 0.8187662983358241
